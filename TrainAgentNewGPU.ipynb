# %% [markdown]
# # Обучение агента в Unity ML-Agents с экспортом ONNX
#
# Этот ноутбук обучает агента из Unity-среды (`MyAgent?team=0`) с 6 наблюдениями и 2 непрерывными действиями (без прыжка). Используем PPO из `stable-baselines3` с поддержкой GPU и экспортируем модель в ONNX для Unity Sentis.
#
# ## Зависимости
# - Установите библиотеки:
#   ```bash
#   pip install mlagents==0.30.0 stable-baselines3==2.0.0 gymnasium==0.28.1 torch==2.0.1+cu118 torchvision==0.15.2+cu118 -f https://download.pytorch.org/whl/torch_stable.html onnx numpy psutil
#   ```
# - Убедитесь, что путь к `UnityEnvironment.exe` правильный.
# - Среда Unity должна быть собрана с `Behavior Name: MyAgent?team=0`, `Continuous Actions: 2`, `Discrete Actions: 0`.
# - Python 3.8, NVIDIA GPU с CUDA 11.8 (или совместимая версия).
# - Проверьте доступность GPU:
#   ```bash
#   python -c "import torch; print(torch.cuda.is_available())"
#   ```

# %%
# !pip3 install mlagents==0.30.0 stable-baselines3==2.0.0 gymnasium==0.28.1 torch==2.0.1+cu118 torchvision==0.15.2+cu118 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: mlagents==0.30.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (0.30.0)
# Requirement already satisfied: stable-baselines3==2.0.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (2.0.0)
# Requirement already satisfied: gymnasium==0.28.1 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (0.28.1)
# Collecting torch==2.0.1+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp38-cp38-win_amd64.whl (2619.2 MB)
#      ---------------------------------------- 0.0/2.6 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.6 GB 21.7 MB/s eta 0:02:01
#      ---------------------------------------- 0.0/2.6 GB 24.0 MB/s eta 0:01:49
#      ---------------------------------------- 0.0/2.6 GB 24.0 MB/s eta 0:01:49
#      ---------------------------------------- 0.0/2.6 GB 23.8 MB/s eta 0:01:50
#      ---------------------------------------- 0.0/2.6 GB 22.6 MB/s eta 0:01:55
#      ---------------------------------------- 0.0/2.6 GB 22.4 MB/s eta 0:01:56
#      ---------------------------------------- 0.0/2.6 GB 21.5 MB/s eta 0:02:01
#      ---------------------------------------- 0.0/2.6 GB 20.3 MB/s eta 0:02:08
#       --------------------------------------- 0.0/2.6 GB 19.1 MB/s eta 0:02:16
#       --------------------------------------- 0.0/2.6 GB 18.5 MB/s eta 0:02:20
#       --------------------------------------- 0.0/2.6 GB 17.9 MB/s eta 0:02:25
#       --------------------------------------- 0.0/2.6 GB 17.5 MB/s eta 0:02:27
#       --------------------------------------- 0.0/2.6 GB 17.2 MB/s eta 0:02:30
#       --------------------------------------- 0.0/2.6 GB 16.8 MB/s eta 0:02:34
#       --------------------------------------- 0.0/2.6 GB 16.4 MB/s eta 0:02:37
#       --------------------------------------- 0.1/2.6 GB 16.2 MB/s eta 0:02:39
#       --------------------------------------- 0.1/2.6 GB 16.1 MB/s eta 0:02:40
#       --------------------------------------- 0.1/2.6 GB 15.8 MB/s eta 0:02:42
#       --------------------------------------- 0.1/2.6 GB 15.7 MB/s eta 0:02:44
#       --------------------------------------- 0.1/2.6 GB 15.4 MB/s eta 0:02:46
#       --------------------------------------- 0.1/2.6 GB 15.3 MB/s eta 0:02:47
#      - -------------------------------------- 0.1/2.6 GB 15.2 MB/s eta 0:02:48
#      - -------------------------------------- 0.1/2.6 GB 15.1 MB/s eta 0:02:49
#      - -------------------------------------- 0.1/2.6 GB 14.9 MB/s eta 0:02:51
#      - -------------------------------------- 0.1/2.6 GB 14.9 MB/s eta 0:02:51
#      - -------------------------------------- 0.1/2.6 GB 14.8 MB/s eta 0:02:52
#      - -------------------------------------- 0.1/2.6 GB 14.7 MB/s eta 0:02:53
#      - -------------------------------------- 0.1/2.6 GB 14.6 MB/s eta 0:02:54
#      - -------------------------------------- 0.1/2.6 GB 14.6 MB/s eta 0:02:54
#      - -------------------------------------- 0.1/2.6 GB 14.5 MB/s eta 0:02:55
#      - -------------------------------------- 0.1/2.6 GB 14.4 MB/s eta 0:02:56
#      - -------------------------------------- 0.1/2.6 GB 14.4 MB/s eta 0:02:57
#      - -------------------------------------- 0.1/2.6 GB 14.3 MB/s eta 0:02:57
#      - -------------------------------------- 0.1/2.6 GB 14.3 MB/s eta 0:02:57
#      - -------------------------------------- 0.1/2.6 GB 14.2 MB/s eta 0:02:58
#      - -------------------------------------- 0.1/2.6 GB 14.2 MB/s eta 0:02:58
#      - -------------------------------------- 0.1/2.6 GB 14.1 MB/s eta 0:02:59
#      - -------------------------------------- 0.1/2.6 GB 14.1 MB/s eta 0:02:59
#      - -------------------------------------- 0.1/2.6 GB 14.0 MB/s eta 0:02:59
#      - -------------------------------------- 0.1/2.6 GB 14.0 MB/s eta 0:02:59
#      - -------------------------------------- 0.1/2.6 GB 13.9 MB/s eta 0:03:00
#      - -------------------------------------- 0.1/2.6 GB 13.9 MB/s eta 0:03:00
#      - -------------------------------------- 0.1/2.6 GB 13.9 MB/s eta 0:03:01
#      - -------------------------------------- 0.1/2.6 GB 13.8 MB/s eta 0:03:01
#      - -------------------------------------- 0.1/2.6 GB 13.8 MB/s eta 0:03:01
#      - -------------------------------------- 0.1/2.6 GB 13.8 MB/s eta 0:03:01
#      -- ------------------------------------- 0.1/2.6 GB 13.8 MB/s eta 0:03:01
#      -- ------------------------------------- 0.1/2.6 GB 13.7 MB/s eta 0:03:01
#      -- ------------------------------------- 0.1/2.6 GB 13.7 MB/s eta 0:03:02
#      -- ------------------------------------- 0.1/2.6 GB 13.7 MB/s eta 0:03:02
#      -- ------------------------------------- 0.1/2.6 GB 13.7 MB/s eta 0:03:02
#      -- ------------------------------------- 0.1/2.6 GB 13.6 MB/s eta 0:03:02
#      -- ------------------------------------- 0.1/2.6 GB 13.6 MB/s eta 0:03:02
#      -- ------------------------------------- 0.1/2.6 GB 13.6 MB/s eta 0:03:02
#      -- ------------------------------------- 0.2/2.6 GB 13.6 MB/s eta 0:03:02
#      -- ------------------------------------- 0.2/2.6 GB 13.6 MB/s eta 0:03:02
#      -- ------------------------------------- 0.2/2.6 GB 13.5 MB/s eta 0:03:03
#      -- ------------------------------------- 0.2/2.6 GB 13.5 MB/s eta 0:03:02
#      -- ------------------------------------- 0.2/2.6 GB 13.5 MB/s eta 0:03:03
#      -- ------------------------------------- 0.2/2.6 GB 13.5 MB/s eta 0:03:03
#      -- ------------------------------------- 0.2/2.6 GB 13.5 MB/s eta 0:03:03
#      -- ------------------------------------- 0.2/2.6 GB 13.5 MB/s eta 0:03:03
#      -- ------------------------------------- 0.2/2.6 GB 13.4 MB/s eta 0:03:03
#      -- ------------------------------------- 0.2/2.6 GB 13.4 MB/s eta 0:03:03
#      -- ------------------------------------- 0.2/2.6 GB 13.4 MB/s eta 0:03:03
#      -- ------------------------------------- 0.2/2.6 GB 13.4 MB/s eta 0:03:03
#      -- ------------------------------------- 0.2/2.6 GB 13.4 MB/s eta 0:03:03
#      -- ------------------------------------- 0.2/2.6 GB 13.4 MB/s eta 0:03:02
#      -- ------------------------------------- 0.2/2.6 GB 13.4 MB/s eta 0:03:03
#      -- ------------------------------------- 0.2/2.6 GB 13.4 MB/s eta 0:03:02
#      -- ------------------------------------- 0.2/2.6 GB 13.3 MB/s eta 0:03:03
#      -- ------------------------------------- 0.2/2.6 GB 13.3 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.3 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.3 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.3 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.3 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.3 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.3 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.3 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.2 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.2 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.2 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.2 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.2 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.2 MB/s eta 0:03:02
#      --- ------------------------------------ 0.2/2.6 GB 13.2 MB/s eta 0:03:01
#      --- ------------------------------------ 0.2/2.6 GB 13.2 MB/s eta 0:03:01
#      --- ------------------------------------ 0.2/2.6 GB 13.2 MB/s eta 0:03:01
#      --- ------------------------------------ 0.2/2.6 GB 13.2 MB/s eta 0:03:01
#      --- ------------------------------------ 0.2/2.6 GB 13.2 MB/s eta 0:03:01
#      --- ------------------------------------ 0.2/2.6 GB 13.2 MB/s eta 0:03:01
#      --- ------------------------------------ 0.2/2.6 GB 13.2 MB/s eta 0:03:01
#      --- ------------------------------------ 0.2/2.6 GB 13.1 MB/s eta 0:03:01
#      --- ------------------------------------ 0.3/2.6 GB 13.1 MB/s eta 0:03:01
#      --- ------------------------------------ 0.3/2.6 GB 13.1 MB/s eta 0:03:01
#      --- ------------------------------------ 0.3/2.6 GB 13.1 MB/s eta 0:03:00
#      --- ------------------------------------ 0.3/2.6 GB 13.1 MB/s eta 0:03:00
#      --- ------------------------------------ 0.3/2.6 GB 13.1 MB/s eta 0:03:00
#      ---- ----------------------------------- 0.3/2.6 GB 13.1 MB/s eta 0:03:00
#      ---- ----------------------------------- 0.3/2.6 GB 13.0 MB/s eta 0:03:01
#      ---- ----------------------------------- 0.3/2.6 GB 12.9 MB/s eta 0:03:02
#      ---- ----------------------------------- 0.3/2.6 GB 12.9 MB/s eta 0:03:03
#      ---- ----------------------------------- 0.3/2.6 GB 12.8 MB/s eta 0:03:03
#      ---- ----------------------------------- 0.3/2.6 GB 12.7 MB/s eta 0:03:04
#      ---- ----------------------------------- 0.3/2.6 GB 12.7 MB/s eta 0:03:05
#      ---- ----------------------------------- 0.3/2.6 GB 12.6 MB/s eta 0:03:06
#      ---- ----------------------------------- 0.3/2.6 GB 12.6 MB/s eta 0:03:06
#      ---- ----------------------------------- 0.3/2.6 GB 12.4 MB/s eta 0:03:08
#      ---- ----------------------------------- 0.3/2.6 GB 12.4 MB/s eta 0:03:09
#      ---- ----------------------------------- 0.3/2.6 GB 12.4 MB/s eta 0:03:09
#      ---- ----------------------------------- 0.3/2.6 GB 12.4 MB/s eta 0:03:07
#      ---- ----------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:06
#      ---- ----------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:07
#      ---- ----------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:05
#      ---- ----------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:05
#      ---- ----------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:05
#      ---- ----------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:05
#      ---- ----------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:05
#      ---- ----------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:05
#      ---- ----------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:04
#      ---- ----------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:04
#      ---- ----------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:04
#      ---- ----------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:04
#      ----- ---------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:04
#      ----- ---------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:03
#      ----- ---------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:03
#      ----- ---------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:03
#      ----- ---------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:02
#      ----- ---------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:02
#      ----- ---------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:02
#      ----- ---------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:02
#      ----- ---------------------------------- 0.3/2.6 GB 12.5 MB/s eta 0:03:02
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:03:02
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:03:02
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:03:01
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:03:01
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:03:01
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:03:01
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:03:00
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:03:00
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:03:00
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:03:00
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:59
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:59
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:59
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:59
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:59
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:58
#      ----- ---------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:58
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:58
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:58
#      ------ --------------------------------- 0.4/2.6 GB 12.6 MB/s eta 0:02:57
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:57
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:57
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:57
#      ------ --------------------------------- 0.4/2.6 GB 12.6 MB/s eta 0:02:57
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:56
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:56
#      ------ --------------------------------- 0.4/2.6 GB 12.6 MB/s eta 0:02:56
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:56
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:56
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:56
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:55
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:55
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:55
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:55
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:54
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:54
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:54
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:54
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:54
#      ------ --------------------------------- 0.4/2.6 GB 12.5 MB/s eta 0:02:54
#      ------ --------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:53
#      ------ --------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:53
#      ------ --------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:53
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:53
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:53
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:52
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:52
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:52
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:52
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:52
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:51
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:51
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:51
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:51
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:51
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:50
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:50
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:50
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:50
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:49
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:49
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:49
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:49
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:49
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:49
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:49
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:49
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:49
#      ------- -------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:48
#      -------- ------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:48
#      -------- ------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:48
#      -------- ------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:48
#      -------- ------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:48
#      -------- ------------------------------- 0.5/2.6 GB 12.4 MB/s eta 0:02:49
#      -------- ------------------------------- 0.5/2.6 GB 12.4 MB/s eta 0:02:48
#      -------- ------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:47
#      -------- ------------------------------- 0.5/2.6 GB 12.5 MB/s eta 0:02:47
#      -------- ------------------------------- 0.5/2.6 GB 12.8 MB/s eta 0:02:43
#      -------- ------------------------------- 0.5/2.6 GB 12.7 MB/s eta 0:02:44
#      -------- ------------------------------- 0.6/2.6 GB 12.7 MB/s eta 0:02:44
#      -------- ------------------------------- 0.6/2.6 GB 12.6 MB/s eta 0:02:45
#      -------- ------------------------------- 0.6/2.6 GB 12.5 MB/s eta 0:02:45
#      -------- ------------------------------- 0.6/2.6 GB 12.5 MB/s eta 0:02:45
#      -------- ------------------------------- 0.6/2.6 GB 12.6 MB/s eta 0:02:44
#      -------- ------------------------------- 0.6/2.6 GB 12.5 MB/s eta 0:02:45
#      -------- ------------------------------- 0.6/2.6 GB 12.5 MB/s eta 0:02:45
#      -------- ------------------------------- 0.6/2.6 GB 12.4 MB/s eta 0:02:45
#      -------- ------------------------------- 0.6/2.6 GB 12.5 MB/s eta 0:02:45
#      -------- ------------------------------- 0.6/2.6 GB 12.4 MB/s eta 0:02:45
#      -------- ------------------------------- 0.6/2.6 GB 12.5 MB/s eta 0:02:45
#      -------- ------------------------------- 0.6/2.6 GB 12.4 MB/s eta 0:02:45
#      -------- ------------------------------- 0.6/2.6 GB 12.5 MB/s eta 0:02:44
#      -------- ------------------------------- 0.6/2.6 GB 12.5 MB/s eta 0:02:44
#      -------- ------------------------------- 0.6/2.6 GB 12.5 MB/s eta 0:02:44
#      -------- ------------------------------- 0.6/2.6 GB 12.4 MB/s eta 0:02:44
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:44
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:43
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:43
#      --------- ------------------------------ 0.6/2.6 GB 12.5 MB/s eta 0:02:43
#      --------- ------------------------------ 0.6/2.6 GB 12.5 MB/s eta 0:02:43
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:43
#      --------- ------------------------------ 0.6/2.6 GB 12.5 MB/s eta 0:02:42
#      --------- ------------------------------ 0.6/2.6 GB 12.5 MB/s eta 0:02:42
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:42
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:42
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:42
#      --------- ------------------------------ 0.6/2.6 GB 12.5 MB/s eta 0:02:41
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:41
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:41
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:41
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:41
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:41
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:40
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:40
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:40
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:40
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:40
#      --------- ------------------------------ 0.6/2.6 GB 12.3 MB/s eta 0:02:41
#      --------- ------------------------------ 0.6/2.6 GB 12.4 MB/s eta 0:02:40
#      --------- ------------------------------ 0.7/2.6 GB 12.4 MB/s eta 0:02:40
#      --------- ------------------------------ 0.7/2.6 GB 12.4 MB/s eta 0:02:39
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:39
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:38
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:38
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:38
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:38
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:38
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:37
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:37
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:37
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:37
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:37
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:36
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:36
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:36
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:36
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:35
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:35
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:35
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:35
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:35
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:35
#      ---------- ----------------------------- 0.7/2.6 GB 12.5 MB/s eta 0:02:34
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:34
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:34
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:34
#      ---------- ----------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:33
#      ----------- ---------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:33
#      ----------- ---------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:33
#      ----------- ---------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:33
#      ----------- ---------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:33
#      ----------- ---------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:33
#      ----------- ---------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:32
#      ----------- ---------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:32
#      ----------- ---------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:32
#      ----------- ---------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:32
#      ----------- ---------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:32
#      ----------- ---------------------------- 0.7/2.6 GB 12.4 MB/s eta 0:02:31
#      ----------- ---------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:31
#      ----------- ---------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:31
#      ----------- ---------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:31
#      ----------- ---------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:31
#      ----------- ---------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:30
#      ----------- ---------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:30
#      ----------- ---------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:30
#      ----------- ---------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:30
#      ----------- ---------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:29
#      ----------- ---------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:29
#      ----------- ---------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:29
#      ----------- ---------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:28
#      ----------- ---------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:28
#      ----------- ---------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:28
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:27
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:27
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:27
#      ------------ --------------------------- 0.8/2.6 GB 12.6 MB/s eta 0:02:26
#      ------------ --------------------------- 0.8/2.6 GB 12.6 MB/s eta 0:02:26
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:26
#      ------------ --------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:27
#      ------------ --------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:26
#      ------------ --------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:26
#      ------------ --------------------------- 0.8/2.6 GB 12.4 MB/s eta 0:02:26
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:26
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:25
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:25
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:25
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:25
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:24
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:24
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:24
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:24
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:23
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:23
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:23
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:23
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:23
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:22
#      ------------ --------------------------- 0.8/2.6 GB 12.5 MB/s eta 0:02:22
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:22
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:22
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:22
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:21
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:21
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:21
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:21
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:20
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:20
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:20
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:20
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:20
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:19
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:19
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:19
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:19
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:19
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:18
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:18
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:18
#      ------------- -------------------------- 0.9/2.6 GB 12.6 MB/s eta 0:02:17
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:17
#      ------------- -------------------------- 0.9/2.6 GB 12.6 MB/s eta 0:02:16
#      ------------- -------------------------- 0.9/2.6 GB 12.6 MB/s eta 0:02:17
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:17
#      ------------- -------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:17
#      -------------- ------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:17
#      -------------- ------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:17
#      -------------- ------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:16
#      -------------- ------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:16
#      -------------- ------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:16
#      -------------- ------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:16
#      -------------- ------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:16
#      -------------- ------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:16
#      -------------- ------------------------- 0.9/2.6 GB 12.5 MB/s eta 0:02:16
#      -------------- ------------------------- 0.9/2.6 GB 12.4 MB/s eta 0:02:16
#      -------------- ------------------------- 0.9/2.6 GB 12.4 MB/s eta 0:02:15
#      -------------- ------------------------- 0.9/2.6 GB 12.4 MB/s eta 0:02:15
#      -------------- ------------------------- 0.9/2.6 GB 12.4 MB/s eta 0:02:15
#      -------------- ------------------------- 0.9/2.6 GB 12.4 MB/s eta 0:02:15
#      -------------- ------------------------- 1.0/2.6 GB 12.5 MB/s eta 0:02:14
#      -------------- ------------------------- 1.0/2.6 GB 12.5 MB/s eta 0:02:14
#      -------------- ------------------------- 1.0/2.6 GB 12.5 MB/s eta 0:02:14
#      -------------- ------------------------- 1.0/2.6 GB 12.5 MB/s eta 0:02:14
#      -------------- ------------------------- 1.0/2.6 GB 12.5 MB/s eta 0:02:13
#      -------------- ------------------------- 1.0/2.6 GB 12.5 MB/s eta 0:02:13
#      -------------- ------------------------- 1.0/2.6 GB 12.4 MB/s eta 0:02:13
#      -------------- ------------------------- 1.0/2.6 GB 12.5 MB/s eta 0:02:13
#      -------------- ------------------------- 1.0/2.6 GB 12.5 MB/s eta 0:02:13
#      -------------- ------------------------- 1.0/2.6 GB 12.5 MB/s eta 0:02:12
#      -------------- ------------------------- 1.0/2.6 GB 12.5 MB/s eta 0:02:12
#      -------------- ------------------------- 1.0/2.6 GB 12.5 MB/s eta 0:02:12
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:12
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:11
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:11
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:11
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:11
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:11
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:10
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:10
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:10
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:10
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:10
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:10
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:09
#      --------------- ------------------------ 1.0/2.6 GB 12.4 MB/s eta 0:02:09
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:09
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:09
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:08
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:08
#      --------------- ------------------------ 1.0/2.6 GB 12.4 MB/s eta 0:02:08
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:08
#      --------------- ------------------------ 1.0/2.6 GB 12.5 MB/s eta 0:02:08
#      --------------- ------------------------ 1.0/2.6 GB 12.4 MB/s eta 0:02:08
#      --------------- ------------------------ 1.0/2.6 GB 12.4 MB/s eta 0:02:08
#      --------------- ------------------------ 1.0/2.6 GB 12.4 MB/s eta 0:02:07
#      --------------- ------------------------ 1.0/2.6 GB 12.4 MB/s eta 0:02:07
#      --------------- ------------------------ 1.0/2.6 GB 12.4 MB/s eta 0:02:07
#      ---------------- ----------------------- 1.0/2.6 GB 12.5 MB/s eta 0:02:07
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:06
#      ---------------- ----------------------- 1.1/2.6 GB 12.5 MB/s eta 0:02:06
#      ---------------- ----------------------- 1.1/2.6 GB 12.5 MB/s eta 0:02:06
#      ---------------- ----------------------- 1.1/2.6 GB 12.5 MB/s eta 0:02:05
#      ---------------- ----------------------- 1.1/2.6 GB 12.5 MB/s eta 0:02:05
#      ---------------- ----------------------- 1.1/2.6 GB 12.5 MB/s eta 0:02:05
#      ---------------- ----------------------- 1.1/2.6 GB 12.5 MB/s eta 0:02:05
#      ---------------- ----------------------- 1.1/2.6 GB 12.5 MB/s eta 0:02:04
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:05
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:05
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:05
#      ---------------- ----------------------- 1.1/2.6 GB 12.5 MB/s eta 0:02:04
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:04
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:04
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:04
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:04
#      ---------------- ----------------------- 1.1/2.6 GB 12.5 MB/s eta 0:02:03
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:03
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:03
#      ---------------- ----------------------- 1.1/2.6 GB 12.5 MB/s eta 0:02:02
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:03
#      ---------------- ----------------------- 1.1/2.6 GB 12.5 MB/s eta 0:02:02
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:02
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:02
#      ---------------- ----------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:02
#      ----------------- ---------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:01
#      ----------------- ---------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:01
#      ----------------- ---------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:01
#      ----------------- ---------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:01
#      ----------------- ---------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:01
#      ----------------- ---------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:00
#      ----------------- ---------------------- 1.1/2.6 GB 12.5 MB/s eta 0:02:00
#      ----------------- ---------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:00
#      ----------------- ---------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:00
#      ----------------- ---------------------- 1.1/2.6 GB 12.4 MB/s eta 0:02:00
#      ----------------- ---------------------- 1.1/2.6 GB 12.4 MB/s eta 0:01:59
#      ----------------- ---------------------- 1.1/2.6 GB 12.4 MB/s eta 0:01:59
#      ----------------- ---------------------- 1.1/2.6 GB 12.4 MB/s eta 0:01:59
#      ----------------- ---------------------- 1.1/2.6 GB 12.4 MB/s eta 0:01:59
#      ----------------- ---------------------- 1.2/2.6 GB 12.4 MB/s eta 0:01:59
#      ----------------- ---------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:58
#      ----------------- ---------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:58
#      ----------------- ---------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:58
#      ----------------- ---------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:58
#      ----------------- ---------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:57
#      ----------------- ---------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:57
#      ----------------- ---------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:57
#      ----------------- ---------------------- 1.2/2.6 GB 12.4 MB/s eta 0:01:57
#      ----------------- ---------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:57
#      ----------------- ---------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:56
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:56
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:56
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:55
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:55
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:55
#      ------------------ --------------------- 1.2/2.6 GB 12.4 MB/s eta 0:01:56
#      ------------------ --------------------- 1.2/2.6 GB 12.4 MB/s eta 0:01:56
#      ------------------ --------------------- 1.2/2.6 GB 12.4 MB/s eta 0:01:56
#      ------------------ --------------------- 1.2/2.6 GB 12.4 MB/s eta 0:01:55
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:54
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:54
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:53
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:53
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:53
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:53
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:53
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:52
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:52
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:52
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:52
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:52
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:51
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:51
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:51
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:51
#      ------------------ --------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:51
#      ------------------- -------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:51
#      ------------------- -------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:50
#      ------------------- -------------------- 1.2/2.6 GB 12.5 MB/s eta 0:01:50
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:50
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:50
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:49
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:49
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:49
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:49
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:49
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:49
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:48
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:48
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:48
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:48
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:48
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:47
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:47
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:47
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:47
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:46
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:46
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:46
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:46
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:46
#      ------------------- -------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:45
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:45
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:45
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:45
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:45
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:44
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:44
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:44
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:44
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:44
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:43
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:43
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:43
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:43
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:43
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:42
#      -------------------- ------------------- 1.3/2.6 GB 12.5 MB/s eta 0:01:42
#      -------------------- ------------------- 1.4/2.6 GB 12.5 MB/s eta 0:01:42
#      -------------------- ------------------- 1.4/2.6 GB 12.5 MB/s eta 0:01:42
#      -------------------- ------------------- 1.4/2.6 GB 12.5 MB/s eta 0:01:42
#      -------------------- ------------------- 1.4/2.6 GB 12.5 MB/s eta 0:01:42
#      -------------------- ------------------- 1.4/2.6 GB 12.5 MB/s eta 0:01:41
#      -------------------- ------------------- 1.4/2.6 GB 12.5 MB/s eta 0:01:41
#      -------------------- ------------------- 1.4/2.6 GB 12.4 MB/s eta 0:01:42
#      -------------------- ------------------- 1.4/2.6 GB 12.4 MB/s eta 0:01:42
#      -------------------- ------------------- 1.4/2.6 GB 12.5 MB/s eta 0:01:41
#      -------------------- ------------------- 1.4/2.6 GB 12.4 MB/s eta 0:01:41
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:40
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:40
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:40
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:40
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:39
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:39
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:39
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:39
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:38
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:38
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:38
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:38
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:38
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:38
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:37
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:37
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:37
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:37
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:37
#      --------------------- ------------------ 1.4/2.6 GB 12.4 MB/s eta 0:01:37
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:36
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:36
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:36
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:35
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:35
#      --------------------- ------------------ 1.4/2.6 GB 12.5 MB/s eta 0:01:35
#      ---------------------- ----------------- 1.4/2.6 GB 12.5 MB/s eta 0:01:35
#      ---------------------- ----------------- 1.4/2.6 GB 12.5 MB/s eta 0:01:35
#      ---------------------- ----------------- 1.4/2.6 GB 12.5 MB/s eta 0:01:35
#      ---------------------- ----------------- 1.4/2.6 GB 12.4 MB/s eta 0:01:35
#      ---------------------- ----------------- 1.5/2.6 GB 12.6 MB/s eta 0:01:33
#      ---------------------- ----------------- 1.5/2.6 GB 12.6 MB/s eta 0:01:33
#      ---------------------- ----------------- 1.5/2.6 GB 12.6 MB/s eta 0:01:33
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:33
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:33
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:33
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:33
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:33
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:33
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:32
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:32
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:32
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:32
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:31
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:31
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:31
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:31
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:31
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:30
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:30
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:30
#      ---------------------- ----------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:30
#      ----------------------- ---------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:30
#      ----------------------- ---------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:29
#      ----------------------- ---------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:29
#      ----------------------- ---------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:29
#      ----------------------- ---------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:29
#      ----------------------- ---------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:29
#      ----------------------- ---------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:28
#      ----------------------- ---------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:28
#      ----------------------- ---------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:28
#      ----------------------- ---------------- 1.5/2.6 GB 12.5 MB/s eta 0:01:28
# ...
#      -------------------------------------- - 2.5/2.6 GB 11.9 MB/s eta 0:00:07
#      -------------------------------------- - 2.5/2.6 GB 11.9 MB/s eta 0:00:07
#      -------------------------------------- - 2.5/2.6 GB 11.9 MB/s eta 0:00:07
#      -------------------------------------- - 2.5/2.6 GB 11.9 MB/s eta 0:00:07
#      -------------------------------------- - 2.5/2.6 GB 11.9 MB/s eta 0:00:06
#      -------------------------------------- - 2.6/2.6 GB 11.9 MB/s eta 0:00:06
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:06
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:06
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:05
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:05
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:05
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:05
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:05
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:04
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:04
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:04
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:04
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:04
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:03
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:03
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:03
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:03
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:02
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:02
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:02
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:02
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:02
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------  2.6/2.6 GB 11.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.6/2.6 GB 8.5 MB/s eta 0:00:00
# Collecting torchvision==0.15.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp38-cp38-win_amd64.whl (4.9 MB)
#      ---------------------------------------- 0.0/4.9 MB ? eta -:--:--
#      --------------------- ------------------ 2.6/4.9 MB 13.7 MB/s eta 0:00:01
#      ---------------------------------------- 4.9/4.9 MB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.11.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from mlagents==0.30.0) (1.70.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from mlagents==0.30.0) (3.11.0)
# Requirement already satisfied: mlagents-envs==0.30.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from mlagents==0.30.0) (0.30.0)
# Requirement already satisfied: numpy<2.0,>=1.13.3 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from mlagents==0.30.0) (1.21.2)
# Requirement already satisfied: Pillow>=4.2.1 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from mlagents==0.30.0) (10.4.0)
# Requirement already satisfied: protobuf>=3.6 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from mlagents==0.30.0) (3.20.3)
# Requirement already satisfied: pyyaml>=3.1.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from mlagents==0.30.0) (6.0.2)
# Requirement already satisfied: tensorboard>=1.15 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from mlagents==0.30.0) (2.14.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from mlagents==0.30.0) (24.2.0)
# Requirement already satisfied: pypiwin32==223 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from mlagents==0.30.0) (223)
# Requirement already satisfied: cattrs<1.7,>=1.1.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from mlagents==0.30.0) (1.5.0)
# Requirement already satisfied: cloudpickle in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from stable-baselines3==2.0.0) (3.1.1)
# Requirement already satisfied: pandas in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from stable-baselines3==2.0.0) (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from stable-baselines3==2.0.0) (3.7.5)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from gymnasium==0.28.1) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from gymnasium==0.28.1) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from gymnasium==0.28.1) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from gymnasium==0.28.1) (8.5.0)
# Requirement already satisfied: filelock in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from torch==2.0.1+cu118) (3.16.1)
# Requirement already satisfied: sympy in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from torch==2.0.1+cu118) (1.13.3)
# Requirement already satisfied: networkx in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from torch==2.0.1+cu118) (3.1)
# Requirement already satisfied: jinja2 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from torch==2.0.1+cu118) (3.1.4)
# Requirement already satisfied: requests in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from torchvision==0.15.2+cu118) (2.32.3)
# Requirement already satisfied: gym>=0.21.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from mlagents-envs==0.30.0->mlagents==0.30.0) (0.26.2)
# Requirement already satisfied: pettingzoo==1.15.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from mlagents-envs==0.30.0->mlagents==0.30.0) (1.15.0)
# Requirement already satisfied: pywin32>=223 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from pypiwin32==223->mlagents==0.30.0) (306)
# Requirement already satisfied: zipp>=3.20 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium==0.28.1) (3.21.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from tensorboard>=1.15->mlagents==0.30.0) (2.3.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from tensorboard>=1.15->mlagents==0.30.0) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from tensorboard>=1.15->mlagents==0.30.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from tensorboard>=1.15->mlagents==0.30.0) (3.7)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from tensorboard>=1.15->mlagents==0.30.0) (75.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from tensorboard>=1.15->mlagents==0.30.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from tensorboard>=1.15->mlagents==0.30.0) (3.0.6)
# Requirement already satisfied: wheel>=0.26 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from tensorboard>=1.15->mlagents==0.30.0) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from requests->torchvision==0.15.2+cu118) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from requests->torchvision==0.15.2+cu118) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from requests->torchvision==0.15.2+cu118) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from requests->torchvision==0.15.2+cu118) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from jinja2->torch==2.0.1+cu118) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from matplotlib->stable-baselines3==2.0.0) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from matplotlib->stable-baselines3==2.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from matplotlib->stable-baselines3==2.0.0) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from matplotlib->stable-baselines3==2.0.0) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from matplotlib->stable-baselines3==2.0.0) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from matplotlib->stable-baselines3==2.0.0) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from matplotlib->stable-baselines3==2.0.0) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from matplotlib->stable-baselines3==2.0.0) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from pandas->stable-baselines3==2.0.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from pandas->stable-baselines3==2.0.0) (2025.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from sympy->torch==2.0.1+cu118) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.30.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.30.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.30.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15->mlagents==0.30.0) (2.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from gym>=0.21.0->mlagents-envs==0.30.0->mlagents==0.30.0) (0.0.8)
# Requirement already satisfied: six>=1.5 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0) (1.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.30.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\.conda\envs\ml_agents\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15->mlagents==0.30.0) (3.3.1)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1
#     Uninstalling torch-2.0.1:
#       Successfully uninstalled torch-2.0.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.1+cu118
#     Uninstalling torchvision-0.19.1+cu118:
#       Successfully uninstalled torchvision-0.19.1+cu118
# Successfully installed torch-2.0.1+cu118 torchvision-0.15.2+cu118

# %%
# Импорт библиотек
import os
import numpy as np
import torch
import torch.nn as nn
from mlagents_envs.environment import UnityEnvironment
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel
from mlagents_envs.base_env import ActionTuple
from stable_baselines3 import PPO
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.env_checker import check_env
import gymnasium as gym
from gymnasium import spaces

# Функция закрытия среды
def close_unity_env(env):
    try:
        if env is not None:
            env.close()
            print('Среда Unity успешно закрыта.')
        else:
            print('Среда не инициализирована.')
    except Exception as e:
        print(f'Ошибка при закрытии среды: {e}')
    finally:
        import psutil
        for proc in psutil.process_iter(['name']):
            if proc.info['name'].lower() == 'unityenvironment.exe':
                proc.kill()
                print(f'Процесс UnityEnvironment.exe (PID: {proc.pid}) принудительно завершён.')
            if 'unity' in proc.info['name'].lower():
                proc.kill()
                print(f"Процесс {proc.info['name']} (PID: {proc.pid}) принудительно завершён.")

# Путь к среде Unity
env_path = os.path.join(os.getcwd(), r'N:\MyRL\My_First_NPC\MyfirstMPC\UnityEnvironment.exe')

# Настройка канала для ускорения симуляции
engine_channel = EngineConfigurationChannel()
engine_channel.set_configuration_parameters(time_scale=20.0, quality_level=0) # Уменьшил для стабильности

# Инициализация среды
try:
    env = UnityEnvironment(file_name=env_path, worker_id=1, base_port=6000, side_channels=[engine_channel], timeout_wait=60)
    env.reset()
except Exception as e:
    print(f'Ошибка инициализации среды: {e}')
    close_unity_env(None)
    raise

# Получение имени поведения
behavior_name = list(env.behavior_specs.keys())[0]
print(f'Behavior Name: {behavior_name}')
spec = env.behavior_specs[behavior_name]

# Проверка спецификации
print(f'Observation size: {spec.observation_specs[0].shape[0]}')
print(f'Continuous action size: {spec.action_spec.continuous_size}')
print(f'Discrete action branches: {spec.action_spec.discrete_branches}')
# Out:
# Behavior Name: MyAgent?team=0
# Observation size: 6
# Continuous action size: 2
# Discrete action branches: ()

# %%
class CustomActorCriticNet(BaseFeaturesExtractor):
    def __init__(self, observation_space, features_dim=128):
        super(CustomActorCriticNet, self).__init__(observation_space, features_dim)
        self.fc1 = nn.Linear(observation_space.shape[0], 128).to(device)
        self.fc2 = nn.Linear(128, 64).to(device)
        self.fc3 = nn.Linear(64, features_dim).to(device)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        return x

policy_kwargs = dict(
    features_extractor_class=CustomActorCriticNet,
    features_extractor_kwargs=dict(features_dim=128),
    net_arch=[dict(pi=[64, 32], vf=[64, 32])]
)

# %%
class UnityGymWrapper(gym.Env):
    def __init__(self, unity_env, behavior_name, spec):
        super(UnityGymWrapper, self).__init__()
        self.env = unity_env
        self.behavior_name = behavior_name
        self.spec = spec
        
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(spec.observation_specs[0].shape[0],), dtype=np.float32
        )
        self.action_space = spaces.Box(
            low=-1.0, high=1.0, shape=(spec.action_spec.continuous_size,), dtype=np.float32
        )

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.env.reset()
        decision_steps, _ = self.env.get_steps(self.behavior_name)
        obs = decision_steps.obs[0][0]
        info = {}
        return obs, info

    def step(self, action):
        # Ensure action is shaped (1, action_size)
        action = np.array(action, dtype=np.float32).reshape(1, -1)
        action_tuple = ActionTuple()
        action_tuple.add_continuous(action)  # Continuous actions only

        self.env.set_actions(self.behavior_name, action_tuple)
        self.env.step()

        decision_steps, terminal_steps = self.env.get_steps(self.behavior_name)
        done = len(terminal_steps) > 0
        if done:
            reward = float(terminal_steps.reward[0])
            obs = terminal_steps.obs[0][0]
        else:
            reward = float(decision_steps.reward[0])
            obs = decision_steps.obs[0][0]
        info = {}
        truncated = False

        return obs, reward, done, truncated, info

    def close(self):
        close_unity_env(self.env)

gym_env = UnityGymWrapper(env, behavior_name, spec)
check_env(gym_env)

# %%
try:
    # Проверяем доступность GPU
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Обучение на устройстве: {device}")

    # Инициализируем модель с указанием устройства
    model = PPO(
        'MlpPolicy',
        gym_env,
        policy_kwargs=policy_kwargs,
        learning_rate=3e-4,
        n_steps=2048,
        batch_size=64,
        n_epochs=10,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        ent_coef=0.01,
        verbose=1,
        device=device
    )

    # Обучение
    model.learn(total_timesteps=100000)
    model.save('ppo_myagent_gpu')

    # Выводим информацию о GPU (если используется)
    if device == 'cuda':
        print(f"Используется GPU: {torch.cuda.get_device_name(0)}")
        print(f"Память GPU: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")

except Exception as e:
    print(f'Ошибка обучения: {e}')
finally:
    close_unity_env(env)
# Out:
# Обучение на устройстве: cuda
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\User\.conda\envs\ML_Agents\lib\site-packages\stable_baselines3\common\policies.py:460: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19       |
# |    ep_rew_mean     | 0.251    |
# | time/              |          |
# |    fps             | 195      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.4        |
# |    ep_rew_mean          | 0.328       |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 2           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004044886 |
# |    clip_fraction        | 0.0169      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | -0.193      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00162    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00206    |
# |    std                  | 1.01        |
# |    value_loss           | 0.0129      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.1        |
# |    ep_rew_mean          | 0.293       |
# | time/                   |             |
# |    fps                  | 168         |
# |    iterations           | 3           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012935042 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.245       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0158     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.997       |
# |    value_loss           | 0.0218      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.4        |
# |    ep_rew_mean          | 0.329       |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 4           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009673376 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0509     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00975    |
# |    std                  | 0.992       |
# |    value_loss           | 0.0223      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 17.4       |
# |    ep_rew_mean          | 0.529      |
# | time/                   |            |
# |    fps                  | 162        |
# |    iterations           | 5          |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01235475 |
# |    clip_fraction        | 0.154      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.81      |
# |    explained_variance   | 0.389      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0398    |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0134    |
# |    std                  | 0.978      |
# |    value_loss           | 0.0191     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.4        |
# |    ep_rew_mean          | 0.588       |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 6           |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010445069 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0321     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.966       |
# |    value_loss           | 0.0306      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.4        |
# |    ep_rew_mean          | 0.605       |
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 7           |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009853151 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.015      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.955       |
# |    value_loss           | 0.0382      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.1       |
# |    ep_rew_mean          | 0.764      |
# | time/                   |            |
# |    fps                  | 154        |
# |    iterations           | 8          |
# |    time_elapsed         | 106        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01503568 |
# |    clip_fraction        | 0.19       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.74      |
# |    explained_variance   | 0.472      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0352    |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0182    |
# |    std                  | 0.948      |
# |    value_loss           | 0.0482     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.2         |
# |    ep_rew_mean          | 0.943        |
# | time/                   |              |
# |    fps                  | 151          |
# |    iterations           | 9            |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0102379965 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.5          |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0397      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00966     |
# |    std                  | 0.941        |
# |    value_loss           | 0.0476       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.5        |
# |    ep_rew_mean          | 0.947       |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 10          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010849891 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0323     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.939       |
# |    value_loss           | 0.0391      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.8        |
# |    ep_rew_mean          | 1.01        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 11          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010973684 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.539       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0242     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00903    |
# |    std                  | 0.934       |
# |    value_loss           | 0.0398      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.2        |
# |    ep_rew_mean          | 1.01        |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 12          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011032958 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0231     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.935       |
# |    value_loss           | 0.0275      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.6        |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 13          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009393908 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0118     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00826    |
# |    std                  | 0.933       |
# |    value_loss           | 0.0226      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.9        |
# |    ep_rew_mean          | 0.999       |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 14          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009543648 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00588    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00812    |
# |    std                  | 0.922       |
# |    value_loss           | 0.0182      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14.9       |
# |    ep_rew_mean          | 1.03       |
# | time/                   |            |
# |    fps                  | 146        |
# |    iterations           | 15         |
# |    time_elapsed         | 209        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01260763 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.66      |
# |    explained_variance   | 0.618      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0514    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00557   |
# |    std                  | 0.912      |
# |    value_loss           | 0.0137     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14          |
# |    ep_rew_mean          | 1.04        |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 16          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013826329 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0351     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0075     |
# |    std                  | 0.908       |
# |    value_loss           | 0.0188      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.6       |
# |    ep_rew_mean          | 1          |
# | time/                   |            |
# |    fps                  | 145        |
# |    iterations           | 17         |
# |    time_elapsed         | 238        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01430136 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.63      |
# |    explained_variance   | 0.752      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0381    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00804   |
# |    std                  | 0.898      |
# |    value_loss           | 0.0182     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.2        |
# |    ep_rew_mean          | 1.1         |
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 18          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.015236739 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.63       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0464     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00771    |
# |    std                  | 0.9         |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13           |
# |    ep_rew_mean          | 1.06         |
# | time/                   |              |
# |    fps                  | 144          |
# |    iterations           | 19           |
# |    time_elapsed         | 269          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0073872195 |
# |    clip_fraction        | 0.0979       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | 0.435        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0247      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00474     |
# |    std                  | 0.891        |
# |    value_loss           | 0.0107       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.2        |
# |    ep_rew_mean          | 1.09        |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 20          |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.020583104 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0595     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00903    |
# |    std                  | 0.901       |
# |    value_loss           | 0.0107      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.3        |
# |    ep_rew_mean          | 1.09        |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 21          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.016765002 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0231     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00259    |
# |    std                  | 0.885       |
# |    value_loss           | 0.00477     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.8       |
# |    ep_rew_mean          | 1.11       |
# | time/                   |            |
# |    fps                  | 143        |
# |    iterations           | 22         |
# |    time_elapsed         | 315        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01360384 |
# |    clip_fraction        | 0.147      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.59      |
# |    explained_variance   | 0.71       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0272    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00352   |
# |    std                  | 0.887      |
# |    value_loss           | 0.00457    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 13.9      |
# |    ep_rew_mean          | 1.07      |
# | time/                   |           |
# |    fps                  | 142       |
# |    iterations           | 23        |
# |    time_elapsed         | 329       |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.0161409 |
# |    clip_fraction        | 0.192     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.61     |
# |    explained_variance   | 0.65      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.047    |
# |    n_updates            | 220       |
# |    policy_gradient_loss | -0.00667  |
# |    std                  | 0.893     |
# |    value_loss           | 0.00518   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.9        |
# |    ep_rew_mean          | 1.1         |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 24          |
# |    time_elapsed         | 344         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.022776334 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0215     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00535    |
# |    std                  | 0.9         |
# |    value_loss           | 0.00421     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.5        |
# |    ep_rew_mean          | 1.05        |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 25          |
# |    time_elapsed         | 359         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012952414 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0302     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00635    |
# |    std                  | 0.879       |
# |    value_loss           | 0.00367     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14.4       |
# |    ep_rew_mean          | 1.05       |
# | time/                   |            |
# |    fps                  | 141        |
# |    iterations           | 26         |
# |    time_elapsed         | 375        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.01445476 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.59      |
# |    explained_variance   | 0.805      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0496    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.00434   |
# |    std                  | 0.889      |
# |    value_loss           | 0.00408    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.8        |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 27          |
# |    time_elapsed         | 389         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.012999946 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0264     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0033      |
# |    std                  | 0.894       |
# |    value_loss           | 0.00535     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.2        |
# |    ep_rew_mean          | 1.07        |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 28          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013829525 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.529       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0166     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00345    |
# |    std                  | 0.871       |
# |    value_loss           | 0.00906     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.3        |
# |    ep_rew_mean          | 1.11        |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 29          |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.016392022 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0449     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00102    |
# |    std                  | 0.862       |
# |    value_loss           | 0.00397     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.5        |
# |    ep_rew_mean          | 1.09        |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 30          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013602844 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0576     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00831    |
# |    std                  | 0.874       |
# |    value_loss           | 0.00567     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.6        |
# |    ep_rew_mean          | 1.07        |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 31          |
# |    time_elapsed         | 450         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.018654767 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.533       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.017      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00704    |
# |    std                  | 0.882       |
# |    value_loss           | 0.00752     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.9        |
# |    ep_rew_mean          | 1.07        |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 32          |
# |    time_elapsed         | 465         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.021731637 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.64        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0575     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00912    |
# |    std                  | 0.875       |
# |    value_loss           | 0.00736     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.2        |
# |    ep_rew_mean          | 1.12        |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 33          |
# |    time_elapsed         | 480         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.010346371 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00744    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00438    |
# |    std                  | 0.878       |
# |    value_loss           | 0.00729     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13          |
# |    ep_rew_mean          | 1.09        |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 34          |
# |    time_elapsed         | 495         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.018978037 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0447     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00307    |
# |    std                  | 0.879       |
# |    value_loss           | 0.00111     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.7        |
# |    ep_rew_mean          | 1.07        |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 35          |
# |    time_elapsed         | 508         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.010280093 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00119     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00293    |
# |    std                  | 0.867       |
# |    value_loss           | 0.00763     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.3        |
# |    ep_rew_mean          | 1.07        |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 36          |
# |    time_elapsed         | 523         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010979924 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.736       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0218     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00683    |
# |    std                  | 0.879       |
# |    value_loss           | 0.00802     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.5        |
# |    ep_rew_mean          | 1.08        |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 37          |
# |    time_elapsed         | 537         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.014265329 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0532     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00715    |
# |    std                  | 0.867       |
# |    value_loss           | 0.00627     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.9        |
# |    ep_rew_mean          | 1.11        |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 38          |
# |    time_elapsed         | 552         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.014687276 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0569     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00592    |
# |    std                  | 0.851       |
# |    value_loss           | 0.00457     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 13.2         |
# |    ep_rew_mean          | 1.11         |
# | time/                   |              |
# |    fps                  | 141          |
# |    iterations           | 39           |
# |    time_elapsed         | 566          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0154997185 |
# |    clip_fraction        | 0.151        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.52        |
# |    explained_variance   | 0.351        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00146      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00609     |
# |    std                  | 0.858        |
# |    value_loss           | 0.00366      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.4        |
# |    ep_rew_mean          | 1.1         |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 40          |
# |    time_elapsed         | 580         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010623805 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.52       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0169     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00771    |
# |    std                  | 0.857       |
# |    value_loss           | 0.00126     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.5        |
# |    ep_rew_mean          | 1.09        |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 41          |
# |    time_elapsed         | 595         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.019504663 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.678       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0497     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00954    |
# |    std                  | 0.868       |
# |    value_loss           | 0.00401     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.1        |
# |    ep_rew_mean          | 1.09        |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 42          |
# |    time_elapsed         | 608         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.017898705 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.656       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0426     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00206    |
# |    std                  | 0.877       |
# |    value_loss           | 0.00841     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.2        |
# |    ep_rew_mean          | 1.1         |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 43          |
# |    time_elapsed         | 623         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.011910981 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0421     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00576    |
# |    std                  | 0.877       |
# |    value_loss           | 0.0032      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.3       |
# |    ep_rew_mean          | 1.12       |
# | time/                   |            |
# |    fps                  | 141        |
# |    iterations           | 44         |
# |    time_elapsed         | 637        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.02170398 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.6       |
# |    explained_variance   | 0.753      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0376    |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00065   |
# |    std                  | 0.893      |
# |    value_loss           | 0.00856    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.4        |
# |    ep_rew_mean          | 1.12        |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 45          |
# |    time_elapsed         | 652         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.018140173 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.717       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0158     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00442    |
# |    std                  | 0.899       |
# |    value_loss           | 0.00182     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.7        |
# |    ep_rew_mean          | 1.09        |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 46          |
# |    time_elapsed         | 666         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009250084 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0282     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00345    |
# |    std                  | 0.897       |
# |    value_loss           | 0.00452     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.2        |
# |    ep_rew_mean          | 1.12        |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 47          |
# |    time_elapsed         | 680         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.013357264 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.686       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0113     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00558    |
# |    std                  | 0.887       |
# |    value_loss           | 0.00304     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.9        |
# |    ep_rew_mean          | 1.13        |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 48          |
# |    time_elapsed         | 694         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.015593236 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0203     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00259    |
# |    std                  | 0.876       |
# |    value_loss           | 0.000539    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.5        |
# |    ep_rew_mean          | 1.09        |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 49          |
# |    time_elapsed         | 709         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.017465372 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | -0.36       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0521     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00567    |
# |    std                  | 0.865       |
# |    value_loss           | 0.00125     |
# -----------------------------------------
# Используется GPU: NVIDIA GeForce GTX 1050 Ti
# Память GPU: 4.00 GB
# Среда Unity успешно закрыта.

# %%
import torch
from torch.nn import Parameter

# Кастомная обёртка для экспорта в ONNX с поддержкой Sentis
class WrapperNet(torch.nn.Module):
    def __init__(self, policy, continuous_action_size):
        super(WrapperNet, self).__init__()
        self.policy = policy

        # version_number: MLAgents2_0 = 3
        version_number = torch.tensor([3], dtype=torch.float32).to(device)
        self.version_number = Parameter(version_number, requires_grad=False)

        # memory_size: 0, так как нет RNN
        memory_size = torch.tensor([0], dtype=torch.float32).to(device)
        self.memory_size = Parameter(memory_size, requires_grad=False)

        # continuous_action_output_shape: [2] для 2 непрерывных действий
        continuous_shape = torch.tensor([continuous_action_size], dtype=torch.float32).to(device)
        self.continuous_shape = Parameter(continuous_shape, requires_grad=False)

    def forward(self, obs, mask):
        continuous_actions = self.policy(obs, deterministic=True)[0]
        continuous_actions = torch.mul(continuous_actions, mask)  # Фиктивное умножение
        return continuous_actions, self.continuous_shape, self.version_number, self.memory_size

try:
    policy = model.policy.to(device)
    continuous_action_size = spec.action_spec.continuous_size  # 2
    wrapper_net = WrapperNet(policy, continuous_action_size)
    
    dummy_input = torch.randn(1, spec.observation_specs[0].shape[0]).to(device)  # [1, 6]
    dummy_mask = torch.ones(1, continuous_action_size).to(device)  # [1, 2]
    
    torch.onnx.export(
        wrapper_net,
        (dummy_input, dummy_mask),
        'trained_myagent.onnx',
        input_names=['obs_0', 'action_masks'],
        output_names=['continuous_actions', 'continuous_action_output_shape', 'version_number', 'memory_size'],
        dynamic_axes={
            'obs_0': {0: 'batch'},
            'action_masks': {0: 'batch'},
            'continuous_actions': {0: 'batch'},
            'continuous_action_output_shape': {0: 'batch'},
            'version_number': {0: 'batch'},
            'memory_size': {0: 'batch'}
        },
        opset_version=9,
        verbose=False
    )
    print('Модель успешно сохранена: trained_myagent.onnx')
    print('Файл существует:', os.path.exists('trained_myagent.onnx'))
except Exception as e:
    print(f'Ошибка экспорта ONNX: {e}')
    print('Попробуйте opset_version=11 или проверьте версию Unity Sentis.')
finally:
    close_unity_env(env)
# Out:
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# Модель успешно сохранена: trained_myagent.onnx
# Файл существует: True
# Ошибка при закрытии среды: No Unity environment is loaded.

# %%
try:
    obs, _ = gym_env.reset()
    for _ in range(1000):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = gym_env.step(action)
        if done or truncated:
            print('Эпизод завершён')
            obs, _ = gym_env.reset()
except Exception as e:
    print(f'Ошибка тестирования: {e}')
finally:
    close_unity_env(env)
# Out:
# Ошибка тестирования: No Unity environment is loaded.
# Ошибка при закрытии среды: No Unity environment is loaded.
